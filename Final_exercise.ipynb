# %% [markdown]
# <a href="https://colab.research.google.com/github/pollicy/Data-ladies-2025/blob/main/Final_exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exercise: Diabetes Progression Prediction
#
# ## Introduction
# In this exercise, you will work with the **Diabetes Dataset** provided by Scikit-Learn.
#
# **The Goal:** Predict the quantitative measure of disease progression one year after baseline, based on 10 baseline variables (age, sex, body mass index, average blood pressure, and six blood serum measurements).
#
# **Type of Task:** Regression

# %% [markdown]
# ### 1. Import Necessary Libraries
# Import pandas, numpy, and the necessary sklearn modules.

# %%
# Import libraries here
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split

# %% [markdown]
# ### 2. Load the Dataset
# The code below loads the dataset and converts it into a Pandas DataFrame for you. Run this cell to get started.

# %%
from sklearn.datasets import load_diabetes

# Load the dataset from sklearn
diabetes_data = load_diabetes()

# Convert to DataFrame
df = pd.DataFrame(diabetes_data.data, columns=diabetes_data.feature_names)

# Add the target variable (Disease Progression)
df['progression'] = diabetes_data.target

print("Dataset Loaded Successfully")

# %% [markdown]
# ### 3. Display the first 5 rows
# Inspect the dataframe to understand what the data looks like.

# %% [markdown]
# ### 4. Check Data Dimensions
# Find out how many rows and columns are in the dataset.

# %% [markdown]
# ### 5. Check for Null Values
# Ensure the dataset is clean by checking if there are any missing values.

# %% [markdown]
# ### 6. Descriptive Statistics
# Generate summary statistics (mean, std, min, max, etc.) for the columns to understand the distribution of data.

# %% [markdown]
# ### 7. Define Features (X) and Target (y)
# Separate the DataFrame into:
# *   **X**: All columns except `progression`.
# *   **y**: The `progression` column.

# %%
X = df.drop('progression', axis=1)
y = df['progression']

# %% [markdown]
# ### 8. Split the Data into Training and Testing sets
# Use `train_test_split` to create `X_train`, `X_test`, `y_train`, and `y_test`.
# *Tip: A common split size is 80% training and 20% testing.*

# %% [markdown]
# ### 9. Initialize and Train the Model
# 1. Initialize a `LinearRegression` model.
# 2. Fit the model using your training data.

# %% [markdown]
# ### 10. Make Predictions
# Use the trained model to make predictions on the **test data** (`X_test`).
